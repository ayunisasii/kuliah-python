# %%
import numpy as np

# %%
from scipy import signal as sg

# %%
import matplotlib.pyplot as plt

# %%
freq = 20
amp = 1
time = np.linspace(0,2,1000)

# %%
signal1 = amp*np.sin(2*np.pi*freq*time)

# %%
plt.plot(time,signal1)

# %%
plt.plot(time,signal1)
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo (V)')
# Out:
# Text(0, 0.5, 'Amplitudo (V)')

# %%
freq1 = 1
amp1 = 3
signal1 = amp1*np.sin(2*np.pi*freq1*time)

# %%
freq2 = 4
amp2 = 0.5
signal2 = amp2*np.sin(2*np.pi*freq2*time)

# %%
freq3 = 7
amp3 = 1
signal3 = amp3*np.sin(2*np.pi*freq3*time)

# %%
signalAll = signal1 + signal2 + signal3 

plt.figure(figsize = (32, 6))
plt.subplot(1,3,1)
plt.plot(time, signal1)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.subplot(1,3,2)
plt.plot(time, signal2)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.subplot(1,3,3)
plt.plot(time, signal3)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
plt.plot(time, signalAll)
plt.xlabel('Time(s)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
plt.plot(time, signalAll)
plt.xlabel('Time(s)')
plt.ylabel('Amplitude')

X = fft(signalAll)
N = len(X)
n = np.arange(N)
T = N/sr
freqFFT = n/T

plt.subplot(1,2,2)
plt.stem(freqFFT, np.abs(X),'b', markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude |X(freq)|')
plt.xlim(0,10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# ### Analisis Sinyal

# %%
from thinkdsp import read_wave
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from thinkdsp import read_wave
#       2 import matplotlib.pyplot as plt
#
# File c:\Users\user\anaconda3\Lib\site-packages\thinkdsp.py:24
#      21 import thinkplot
#      22 import warnings
# ---> 24 from fractions import gcd
#      25 from wave import open as open_wave
#      27 import matplotlib.pyplot as pyplot
#
# ImportError: cannot import name 'gcd' from 'fractions' (c:\Users\user\anaconda3\Lib\fractions.py)

# %%
debussy = read_wave('debussy.wav')
debussy.make_audio()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 debussy = read_wave('debussy.wav')
#       2 debussy.make_audio()
#
# NameError: name 'read_wave' is not defined

# %%
# Get thinkdsp.py

import os

if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import matplotlib.pyplot as plt

from thinkdsp import decorate
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 from thinkdsp import decorate
#
# File c:\Users\user\anaconda3\Lib\site-packages\thinkdsp.py:24
#      21 import thinkplot
#      22 import warnings
# ---> 24 from fractions import gcd
#      25 from wave import open as open_wave
#      27 import matplotlib.pyplot as pyplot
#
# ImportError: cannot import name 'gcd' from 'fractions' (c:\Users\user\anaconda3\Lib\fractions.py)

# %%
if not os.path.exists('92002__jcveliz__violin-origional.wav'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/92002__jcveliz__violin-origional.wav
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from_future_import 

import thinkdsp
import thinkplot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from_future_import
#       3 import thinkdsp
#       4 import thinkplot
#
# NameError: name 'from_future_import' is not defined

# %%
import copy
import math

import numpy as np
import random
import scipy
import scipy.stats
import scipy.fftpack
import subprocess
import warnings

from wave import open as open_wave
from scipy.io import wavfile

import matplotlib.pyplot as plt

try:
    from IPython.display import Audio
except ImportError:
    warnings.warn(
        "Can't import Audio from IPython.display; " "Wave.make_audio() will not work."
    )

PI2 = math.pi * 2

# %%
from wave import open as open_wave
from scipy.io import wavfile

# %%
import matplotlib.pyplot as plt

# %%
instrument = open_wave('debussy.wav')

# %%
print(instrument)

# %%
audio_data = 'debussy.wav'

# %%
audio_data = 'debussy.wav'

# %%
import IPython.display as ipd

# %%
debussy = open_wave('debussy.wav')
